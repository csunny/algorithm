# %%
import math
import numpy as np
import torch
from torch import nn
from d2l import torch as d2l

# %%
max_degree = 20  # 多项式最大阶数
n_train, n_test = 100, 100 # 训练和测试数据集大小
true_w = np.zeros(max_degree)  # 分配大量的空间
true_w[0:4] = np.array([5, 1.2, -3.4, 5.6])
features = np.random.normal(size=(n_train, n_test, 1))
np.random.shuffle(features)

poly_features = np.power(features, np.arange(max_degree).reshape(1, -1))
for i in range(max_degree):
    poly_features[:, i] /= math.gamma(i+1) 

labels = np.dot(poly_features, true_w)
labels += np.random.normal(scale=0.1, size=labels.shape)


true_w, features, poly_features, labels = [torch.tensor(x, dtype=torch.float32) 
    for x in [true_w, features, poly_features, labels]
]


features[:2],poly_features[:2, :], labels[:2]
# Out:
# (tensor([[[-0.6222],
#           [ 0.7547],
#           [-0.5774],
#           [-0.9120],
#           [-0.7717],
#           [ 1.4294],
#           [ 0.2248],
#           [-0.8641],
#           [ 0.3269],
#           [-0.4855],
#           [-0.0682],
#           [-0.5832],
#           [ 0.5844],
#           [ 0.2939],
#           [-0.6782],
#           [ 1.3773],
#           [ 0.3265],
#           [-0.1559],
#           [-0.3252],
#           [ 0.2455],
#           [-0.4123],
#           [ 0.2273],
#           [-1.0948],
#           [ 0.9367],
#           [ 0.6421],
#           [-0.2045],
#           [-0.4763],
#           [ 1.3464],
#           [-0.7397],
#           [-0.5519],
#           [ 0.4160],
#           [-0.1871],
#           [-0.6196],
#           [ 0.7816],
#           [-0.5813],
#           [-2.0020],
#           [ 0.5140],
#           [-2.2850],
#           [ 1.5844],
#           [ 1.9564],
#           [ 0.7572],
#           [-1.0117],
#           [-0.9352],
#           [-0.1824],
#           [-0.1068],
#           [-1.1081],
#           [ 0.6033],
#           [ 0.2417],
#           [ 1.2461],
#           [-1.8644],
#           [-1.0318],
#           [-1.9501],
#           [-0.2244],
#           [-0.4567],
#           [-1.2933],
#           [-0.5172],
#           [ 0.9872],
#           [ 1.1018],
#           [-0.9665],
#           [-0.2424],
#           [ 0.6456],
#           [ 2.0477],
#           [-0.1994],
#           [-0.5346],
#           [-1.3305],
#           [ 0.3957],
#           [ 0.5660],
#           [ 0.7679],
#           [-0.6963],
#           [-0.8315],
#           [ 0.6616],
#           [ 0.6766],
#           [-0.2452],
#           [-1.4490],
#           [-0.1995],
#           [-1.5925],
#           [-0.5674],
#           [ 1.1864],
#           [ 1.6564],
#           [-0.0925],
#           [-0.5906],
#           [-1.7361],
#           [-0.8280],
#           [-0.7179],
#           [ 0.2985],
#           [-0.6629],
#           [-1.6865],
#           [ 0.5179],
#           [-0.4904],
#           [ 0.1705],
#           [-0.7378],
#           [-0.2522],
#           [-0.2948],
#           [-0.2755],
#           [-0.1172],
#           [ 2.2103],
#           [-0.6838],
#           [ 1.2493],
#           [-0.3699],
#           [-0.2981]],
#
#          [[ 2.1394],
#           [ 2.1389],
#           [ 0.0672],
#           [ 0.5371],
#           [-0.7089],
#           [ 1.5160],
#           [-1.4827],
#           [-1.3816],
#           [-0.1080],
#           [-1.1159],
#           [ 0.0252],
#           [ 0.4767],
#           [ 2.2806],
#           [ 0.1479],
#           [ 0.6841],
#           [ 0.7848],
#           [ 0.5026],
#           [-0.3223],
#           [-1.7119],
#           [ 0.1043],
#           [-0.4259],
#           [ 1.3148],
#           [-0.1421],
#           [-1.4419],
#           [-0.1187],
#           [-0.3056],
#           [-0.0648],
#           [ 0.9556],
#           [ 0.9869],
#           [-1.0957],
#           [ 0.1163],
#           [-0.0586],
#           [-1.8234],
#           [-0.4024],
#           [ 0.1601],
#           [-0.5052],
#           [ 0.3708],
#           [ 0.2517],
#           [-0.1179],
#           [-0.1184],
#           [-1.3858],
#           [-2.1037],
#           [-0.6564],
#           [-0.4663],
#           [-0.4659],
#           [-1.1124],
#           [-1.0849],
#           [ 0.5408],
#           [ 0.7792],
#           [-0.3377],
#           [ 0.0189],
#           [-1.0253],
#           [ 1.1739],
#           [ 0.9781],
#           [ 0.7003],
#           [-2.0488],
#           [-1.2577],
#           [ 0.9091],
#           [-1.5453],
#           [-0.8655],
#           [-0.7782],
#           [ 0.3167],
#           [ 1.1080],
#           [ 0.2180],
#           [-0.8202],
#           [-0.3453],
#           [ 1.4844],
#           [-0.3641],
#           [ 0.2966],
#           [-0.3255],
#           [-1.0888],
#           [ 0.3216],
#           [ 0.7994],
#           [-0.4137],
#           [-0.7213],
#           [-0.2656],
#           [-0.1413],
#           [-1.1075],
#           [ 1.9101],
#           [-0.0217],
#           [ 1.2101],
#           [-0.4611],
#           [ 1.1398],
#           [-2.0134],
#           [ 0.9999],
#           [ 1.0704],
#           [-1.1496],
#           [-0.4299],
#           [-1.3730],
#           [-1.4094],
#           [ 0.8869],
#           [-1.1886],
#           [ 0.2305],
#           [ 0.7348],
#           [ 1.3933],
#           [ 0.8639],
#           [-1.0500],
#           [-0.1878],
#           [-0.8310],
#           [-0.3126]]]),
#  tensor([[[ 1.0000e+00, -6.2224e-01,  3.8719e-01,  ..., -3.1429e-04,
#             1.9556e-04, -1.2169e-04],
#           [ 1.0000e+00,  7.5467e-01,  5.6952e-01,  ...,  8.3531e-03,
#             6.3038e-03,  4.7573e-03],
#           [ 5.0000e-01, -2.8868e-01,  1.6667e-01,  ..., -4.4016e-05,
#             2.5413e-05, -1.4673e-05],
#           ...,
#           [ 1.0000e+00,  1.2493e+00,  1.5607e+00,  ...,  4.3977e+01,
#             5.4939e+01,  6.8635e+01],
#           [ 1.0000e+00, -3.6988e-01,  1.3681e-01,  ..., -4.5401e-08,
#             1.6793e-08, -6.2114e-09],
#           [ 1.0000e+00, -2.9810e-01,  8.8864e-02,  ..., -1.1593e-09,
#             3.4558e-10, -1.0302e-10]],
#
#          [[ 1.0000e+00,  2.1394e+00,  4.5769e+00,  ...,  4.1193e+05,
#             8.8126e+05,  1.8853e+06],
#           [ 1.0000e+00,  2.1389e+00,  4.5751e+00,  ...,  4.1056e+05,
#             8.7816e+05,  1.8783e+06],
#           [ 5.0000e-01,  3.3620e-02,  2.2606e-03,  ...,  5.8703e-21,
#             3.9472e-22,  2.6541e-23],
#           ...,
#           [ 1.0000e+00, -1.8779e-01,  3.5266e-02,  ..., -4.4927e-13,
#             8.4370e-14, -1.5844e-14],
#           [ 1.0000e+00, -8.3100e-01,  6.9055e-01,  ..., -4.2972e-02,
#             3.5710e-02, -2.9674e-02],
#           [ 1.0000e+00, -3.1255e-01,  9.7689e-02,  ..., -2.5924e-09,
#             8.1027e-10, -2.5325e-10]]]),
#  tensor([[ 1.4345e+00,  6.3810e+00,  8.8894e-01, -6.4566e-01,  2.0274e-02,
#            2.5489e-01, -9.9534e-02,  1.8354e-02, -6.7695e-02, -4.6510e-02,
#            5.6983e-02,  1.9975e-01, -2.6349e-02,  1.2387e-01, -1.1887e-01,
#           -3.8790e-02, -1.0533e-01,  1.9199e-01, -2.5998e-02,  1.3984e-01,
